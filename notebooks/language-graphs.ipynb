# %%
import pandas as pd
import numpy as np

# %%
data_dir = "../datasets/lang2lang"

# %%
clics = pd.read_csv(f"{data_dir}/clics3_jaccard.csv",index_col=0)

# %%
clics.shape
# Out:
# (1347, 1347)

# %%
df_feat = pd.read_csv("../datasets/lang2vec_distances/SYNTACTIC.csv",index_col=0)

# %%
df_feat
# Out:
#            aap     aca     acu     adc     adw     agr     ake     ako  \
# G_CODE
# aap     0.0002  0.7097  0.7627  0.0002  0.0002  0.8705  0.0002  0.0002
# aca     0.7097  0.0003  0.7939  0.7097  0.7097  0.8526  0.7097  0.7097
# acu     0.7627  0.7939  0.0000  0.7627  0.7627  0.6257  0.7627  0.7627
# adc     0.0002  0.7097  0.7627  0.0002  0.0002  0.8705  0.0002  0.0002
# adw     0.0002  0.7097  0.7627  0.0002  0.0002  0.8705  0.0002  0.0002
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# zsk     0.0002  0.7097  0.7627  0.0002  0.0002  0.8705  0.0002  0.0002
# zxx     0.0002  0.7097  0.7627  0.0002  0.0002  0.8705  0.0002  0.0002
# zza     0.0002  0.7097  0.7627  0.0002  0.0002  0.8705  0.0002  0.0002
# bvs     0.0002  0.7097  0.7627  0.0002  0.0002  0.8705  0.0002  0.0002
# mhv     0.0002  0.7097  0.7627  0.0002  0.0002  0.8705  0.0002  0.0002
#
#            alc     amc  ...     zkh     zkn     zkv     zkz     zra     zsk  \
# ...

# %%
df_feat.dropna()
# Out:
#            aap     aca     acu     adc     adw     agr     ake     ako  \
# G_CODE
# aap     0.0002  0.7097  0.7627  0.0002  0.0002  0.8705  0.0002  0.0002
# aca     0.7097  0.0003  0.7939  0.7097  0.7097  0.8526  0.7097  0.7097
# acu     0.7627  0.7939  0.0000  0.7627  0.7627  0.6257  0.7627  0.7627
# adc     0.0002  0.7097  0.7627  0.0002  0.0002  0.8705  0.0002  0.0002
# adw     0.0002  0.7097  0.7627  0.0002  0.0002  0.8705  0.0002  0.0002
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# zsk     0.0002  0.7097  0.7627  0.0002  0.0002  0.8705  0.0002  0.0002
# zxx     0.0002  0.7097  0.7627  0.0002  0.0002  0.8705  0.0002  0.0002
# zza     0.0002  0.7097  0.7627  0.0002  0.0002  0.8705  0.0002  0.0002
# bvs     0.0002  0.7097  0.7627  0.0002  0.0002  0.8705  0.0002  0.0002
# mhv     0.0002  0.7097  0.7627  0.0002  0.0002  0.8705  0.0002  0.0002
#
#            alc     amc  ...     zkh     zkn     zkv     zkz     zra     zsk  \
# ...
